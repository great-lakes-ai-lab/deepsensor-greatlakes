# %%
import xarray as xr
import netCDF4

# %%
ds = xr.open_dataset("active_learning_uncertainty_map.nc")
ds
# Out:
# <xarray.Dataset> Size: 867MB
# Dimensions:         (iteration: 3, lat: 838, lon: 1181, time: 73)
# Coordinates:
#   * iteration       (iteration) int64 24B 0 1 2
#   * lat             (lat) float64 7kB 38.87 38.89 38.9 ... 50.58 50.59 50.61
#   * lon             (lon) float64 9kB -92.42 -92.41 -92.39 ... -75.9 -75.88
#   * time            (time) datetime64[ns] 584B 2022-01-01 ... 2022-12-27
# Data variables:
#     acquisition_fn  (iteration, time, lat, lon) float32 867MB ...

# %%
ds2D = ds['acquisition_fn'].isel(time=20, iteration=2)
ds2D.plot()
